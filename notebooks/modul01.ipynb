# %% [markdown]
# # Topik 1 - Pengantar Python

# %% [markdown]
# Ini adalah catatan modul 1 dari <b>Netacad Phyton</b>.

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# ## Subheading 1

# %%
print("subheading1")
# Out:
# subheading1

# %% [markdown]
# ## Subheading 2

# %% [markdown]
# ### Subsubheading 2.1

# %% [markdown]
# catatan yang ada disini

# %% [markdown]
# ## Subheading 3
